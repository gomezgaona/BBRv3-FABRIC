# %% [markdown]
# # Evaluating BBRv3 Performance over FABRIC

# %% [markdown]
# ### Topology

# %% [markdown]
# <img src="files/topo.png" width="850px"><br>

# %% [markdown]
# # Step 1:  Configuring the environment
#
# Before running this notebook, you will need to configure your environment using the [Configure Environment](../../../configure_and_validate.ipynb) notebook. Please stop here, open and run that notebook, then return to this notebook.
#
# If you are using the FABRIC JupyterHub many of the environment variables will be automatically configured for you.  You will still need to set your bastion username, upload your bastion private key, and set the path to where you put your bastion private key. Your bastion username and private key should already be in your possession.
#
# If you are using the FABRIC API outside of the JupyterHub you will need to configure all of the environment variables. Defaults below will be correct in many situations but you will need to confirm your configuration.  If you have questions about this configuration, please contact the FABRIC admins using the [FABRIC User Forum](https://learn.fabric-testbed.net/forums/)
#
# More information about accessing your experiments through the FABRIC bastion hosts can be found [here](https://learn.fabric-testbed.net/knowledge-base/logging-into-fabric-vms/).

# %% [markdown]
# # Step 2: Importing the FABlib library

# %%
import json
import traceback
from fabrictestbed_extensions.fablib.fablib import fablib

# %% [markdown]
# # Step 3: Creating the experiment slice
#
# The following creates a node with basic compute and networking capabilities. You build a slice by creating a new slice and adding resources to the slice. After you build the slice, you must submit a request for the slice to be instantiated.

# %% [markdown]
# ### 3.1 Configuring Slice Parameters

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

# Slice 
slice_name = 'bbr3_test'

#[site1,site2] = fablib.get_random_sites(count=2)
site1="NEWY"
site2="DALL"
print(f"Sites: {site1},{site2}")

# Switches
s1_name = "s1"
s2_name = "s2"

switch_cores = 8
switch_ram = 16
switch_disk = 20

# Hosts
h1_name = "h1"
h2_name = "h2"

h1_subnet=IPv4Network('172.16.0.0/16')
h1_addr=IPv4Address('172.16.255.10')
s1_addr1=IPv4Address('172.16.255.254')

h2_subnet=IPv4Network('172.17.0.0/16')
h2_addr=IPv4Address('172.17.255.10')
s2_addr1=IPv4Address('172.17.255.254')

s1_subnet=IPv4Network('192.168.12.0/30')
s1_addr2=IPv4Address('192.168.12.1')

s2_subnet=IPv4Network('192.168.12.0/30')
s2_addr2=IPv4Address('192.168.12.2')

host_cores = 16
host_ram = 32
host_disk = 20

net_h1_name = 'net_h1'
net_h2_name = 'net_h2'

net_s1_s2_name = 'net_s1_s2'

# All node properties
image = 'default_ubuntu_22'
# Out:
# Sites: NEWY,DALL

# %% [markdown]
# ### 3.2 Creating the Slice
#
# This step takes around 3-4 minutes

# %%
try:
    #Create Slice
    slice = fablib.new_slice(name=slice_name)

    # Add switch node s1
    s1 = slice.add_node(name=s1_name, site=site1,  image=image, 
                        cores=switch_cores, ram=switch_ram, disk=switch_disk)
    s1.set_capacities(cores=switch_cores, ram=switch_ram, disk=switch_disk)
    s1_iface_1 = s1.add_component(model='NIC_Basic', name="s1_switch_nic1").get_interfaces()[0]
    s1_iface_2 = s1.add_component(model='NIC_Basic', name="s1_switch_nic2").get_interfaces()[0]

     # Add switch node s1
    s2 = slice.add_node(name=s2_name, site=site2,  image=image, 
                        cores=switch_cores, ram=switch_ram, disk=switch_disk)
    s2.set_capacities(cores=switch_cores, ram=switch_ram, disk=switch_disk)
    s2_iface_1 = s2.add_component(model='NIC_Basic', name="s2_switch_nic1").get_interfaces()[0]
    s2_iface_2 = s2.add_component(model='NIC_Basic', name="s2_switch_nic2").get_interfaces()[0]
    
    # Add host node h1
    h1 = slice.add_node(name=h1_name, site=site1, image=image,
                        cores=host_cores, ram=host_ram, disk=host_disk)
    h1_iface = h1.add_component(model='NIC_Basic', name="h1_nic").get_interfaces()[0]
    
    # Add host node h2
    h2 = slice.add_node(name=h2_name, site=site2, image=image,
                        cores=host_cores, ram=host_ram, disk=host_disk)
    h2_iface = h2.add_component(model='NIC_Basic', name="h2_nic").get_interfaces()[0]
    
    #Add host networks 
    host_net1 = slice.add_l2network(name=net_h1_name, interfaces=[h1_iface, s1_iface_1])
    switch_net1 = slice.add_l2network(name=net_s1_s2_name, interfaces=[s1_iface_2, s2_iface_2])
    host_net2 = slice.add_l2network(name=net_h2_name, interfaces=[h2_iface, s2_iface_1])
    
    #Submit Slice Request
    slice.submit() 
except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc()
# Out:
# Retry: 8, Time: 226 sec
# <style type="text/css">
# #T_ded58 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ded58 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ded58 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_ded58_row0_col0, #T_ded58_row0_col1, #T_ded58_row1_col0, #T_ded58_row1_col1, #T_ded58_row2_col0, #T_ded58_row2_col1, #T_ded58_row3_col0, #T_ded58_row3_col1, #T_ded58_row4_col0, #T_ded58_row4_col1, #T_ded58_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_ded58_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_ded58">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ded58_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_ded58_row0_col1" class="data row0 col1" >7e91dd27-89c0-497c-b570-863e4841af8e</td>
#     </tr>
#     <tr>
#       <td id="T_ded58_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_ded58_row1_col1" class="data row1 col1" >bbr3_test</td>
#     </tr>
#     <tr>
#       <td id="T_ded58_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_ded58_row2_col1" class="data row2 col1" >2025-01-15 17:50:21 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ded58_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_ded58_row3_col1" class="data row3 col1" >2025-01-14 17:50:21 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ded58_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_ded58_row4_col1" class="data row4 col1" >8eaa3ec2-65e7-49a3-8c09-e1761141a6ad</td>
#     </tr>
#     <tr>
#       <td id="T_ded58_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_ded58_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_68a99 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_68a99 th {
#   text-align: left;
# }
# #T_68a99 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_68a99 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_68a99 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_68a99_row0_col0, #T_68a99_row0_col1, #T_68a99_row0_col2, #T_68a99_row0_col3, #T_68a99_row0_col4, #T_68a99_row0_col5, #T_68a99_row0_col6, #T_68a99_row0_col7, #T_68a99_row0_col8, #T_68a99_row0_col9, #T_68a99_row0_col10, #T_68a99_row0_col13, #T_68a99_row0_col14, #T_68a99_row0_col15, #T_68a99_row1_col0, #T_68a99_row1_col1, #T_68a99_row1_col2, #T_68a99_row1_col3, #T_68a99_row1_col4, #T_68a99_row1_col5, #T_68a99_row1_col6, #T_68a99_row1_col7, #T_68a99_row1_col8, #T_68a99_row1_col9, #T_68a99_row1_col10, #T_68a99_row1_col13, #T_68a99_row1_col14, #T_68a99_row1_col15, #T_68a99_row2_col0, #T_68a99_row2_col1, #T_68a99_row2_col2, #T_68a99_
row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_68a99_row2_col7" class="data row2 col7" >newy-w1.fabric-testbed.net</td>
#       <td id="T_68a99_row2_col8" class="data row2 col8" >NEWY</td>
#       <td id="T_68a99_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_68a99_row2_col10" class="data row2 col10" >2001:400:a100:3040:f816:3eff:fe16:ce4</td>
#       <td id="T_68a99_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_68a99_row2_col12" class="data row2 col12" ></td>
#       <td id="T_68a99_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3040:f816:3eff:fe16:ce4</td>
#       <td id="T_68a99_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_68a99_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_68a99_row3_col0" class="data row3 col0" >be643bcf-bd80-45d1-aef8-1985367b1aab</td>
#       <td id="T_68a99_row3_col1" class="data row3 col1" >s2</td>
#       <td id="T_68a99_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_68a99_row3_col3" class="data row3 col3" >16</td>
#       <td id="T_68a99_row3_col4" class="data row
# <style type="text/css">
# #T_3c8fb caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_3c8fb th {
#   text-align: left;
# }
# #T_3c8fb tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3c8fb tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_3c8fb .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3c8fb_row0_col0, #T_3c8fb_row0_col1, #T_3c8fb_row0_col2, #T_3c8fb_row0_col3, #T_3c8fb_row0_col4, #T_3c8fb_row0_col5, #T_3c8fb_row0_col6, #T_3c8fb_row1_col0, #T_3c8fb_row1_col1, #T_3c8fb_row1_col2, #T_3c8fb_row1_col3, #T_3c8fb_row1_col4, #T_3c8fb_row1_col5, #T_3c8fb_row1_col6, #T_3c8fb_row2_col0, #T_3c8fb_row2_col1, #T_3c8fb_row2_col2, #T_3c8fb_row2_col3, #T_3c8fb_row2_col4, #T_3c8fb_row2_col5, #T_3c8fb_row2_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_3c8fb_row0_col7, #T_3c8fb_row1_col7, #T_3c8fb_row2_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_3c8fb_row0_col8, #T_3c8fb_row1_col8, #T_3c8fb_row2_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_3c8fb">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_3c8fb_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_3c8fb_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_3c8fb_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_3c8fb_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_3c8fb_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_3c8fb_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_3c8fb_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_3c8fb_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_3c8fb_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3c8fb_row0_col0" class="data row0 col0" >87fba89c-6c59-4e0b-a66f-24e230a33735</td>
#       <td id="T_3c8fb_row0_col1" class="data row0 col1" >net_h1</td>
#       <td id="T_3c8fb_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_3c8fb_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_3c8fb_row0_col4" class="data row0 col4" >NEWY</td>
#       <td id="T_3c8fb_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_3c8fb_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_3c8fb_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_3c8fb_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_3c8fb_row1_col0" class="data row1 col0" >a099e0e3-0bbd-4d58-b707-98a8fa14a96c</td>
#       <td id="T_3c8fb_row1_col1" class="data row1 col1" >net_h2</td>
#       <td id="T_3c8fb_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_3c8fb_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_3c8fb_row1_col4" class="data row1 col4" >DALL</td>
#       <td id="T_3c8fb_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_3c8fb_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_3c8fb_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_3c8fb_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_3c8fb_row2_col0" class="data row2 col0" >f5ce5b00-5b1e-4e30-a8c6-86c41ff3c37c</td>
#       <td id="T_3c8fb_row2_col1" class="data row2 col1" >net_s1_s2</td>
#       <td id="T_3c8fb_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_3c8fb_row2_col3" class="data row2 col3" >L2STS</td>
#       <td id="T_3c8fb_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_3c8fb_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_3c8fb_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_3c8fb_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T
#       <td id="T_5e579_row4_col7" class="data row4 col7" >06:21:1C:D3:8B:F9</td>
#       <td id="T_5e579_row4_col8" class="data row4 col8" >enp7s0</td>
#       <td id="T_5e579_row4_col9" class="data row4 col9" >enp7s0</td>
#       <td id="T_5e579_row4_col10" class="data row4 col10" >fe80::421:1cff:fed3:8bf9</td>
#       <td id="T_5e579_row4_col11" class="data row4 col11" >4</td>
#       <td id="T_5e579_row4_col12" class="data row4 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <
# Time to print interfaces 242 seconds

# %% [markdown]
# ### 3.3 Installing BBRv3 Kernel Module

# %%
h1 = slice.get_node(name="h1")     
h1.upload_file('kernel_module/linux-headers-6.4.0-bbrv3_6.4.0-g7542cc7c41c0-1_amd64.deb', 'linux-headers-6.4.0-bbrv3_6.4.0-g7542cc7c41c0-1_amd64.deb')
h1.upload_file('kernel_module/linux-image-6.4.0-bbrv3_6.4.0-g7542cc7c41c0-1_amd64.deb', 'linux-image-6.4.0-bbrv3_6.4.0-g7542cc7c41c0-1_amd64.deb')
h1.execute("sudo dpkg -i linux-headers-6.4.0-bbrv3_6.4.0-g7542cc7c41c0-1_amd64.deb")
h1.execute("sudo dpkg -i linux-image-6.4.0-bbrv3_6.4.0-g7542cc7c41c0-1_amd64.deb")
h1.execute("echo 'net.ipv4.tcp_congestion_control=bbr' | sudo tee -a /etc/sysctl.conf")
h1.execute("sudo rm *.deb")
h1.execute("sudo sysctl -p")
#h1.execute("sysctl net.ipv4.tcp_congestion_control")
h1.execute("sudo reboot")
# Out:
# Selecting previously unselected package linux-headers-6.4.0-bbrv3.
# (Reading database ... 64476 files and directories currently installed.)
# Preparing to unpack linux-headers-6.4.0-bbrv3_6.4.0-g7542cc7c41c0-1_amd64.deb ...
# Unpacking linux-headers-6.4.0-bbrv3 (6.4.0-g7542cc7c41c0-1) ...
# Setting up linux-headers-6.4.0-bbrv3 (6.4.0-g7542cc7c41c0-1) ...
# Selecting previously unselected package linux-image-6.4.0-bbrv3.
# (Reading database ... 74724 files and directories currently installed.)
# Preparing to unpack linux-image-6.4.0-bbrv3_6.4.0-g7542cc7c41c0-1_amd64.deb ...
# Unpacking linux-image-6.4.0-bbrv3 (6.4.0-g7542cc7c41c0-1) ...
# Setting up linux-image-6.4.0-bbrv3 (6.4.0-g7542cc7c41c0-1) ...
#  update-initramfs: Generating /boot/initrd.img-6.4.0-bbrv3
#   Sourcing file `/etc/default/grub'
#   Sourcing file `/etc/default/grub.d/50-cloudimg-settings.cfg'
#   Sourcing file `/etc/default/grub.d/init-select.cfg'
# Generating grub configuration file ...
#   Found linux image: /boot/vmlinuz-6.4.0-bbrv3
#   Found initrd image: /boot/initrd.img-6.4.0-bbrv3
#   Found linux image: /boot/vmlinuz-5.15.0-127-generic
#   Found initrd image: /boot/initrd.img-5.15.0-127-generic
#   Warning: os-prober will not be executed to detect other bootable partitions.
# Systems on them will not be added to the GRUB boot configuration.
# Check GRUB_DISABLE_OS_PROBER documentation entry.
#   done
#  net.ipv4.tcp_congestion_control=bbr
# net.ipv4.tcp_congestion_control = bbr
# ('', '')

# %% [markdown]
# ### 3.4 Verifying the Kernel Module Installation

# %%
h1.execute("uname -a")
h1.execute("sysctl net.ipv4.tcp_available_congestion_control")
# Out:
# Linux h1 6.4.0-bbrv3 #1 SMP PREEMPT_DYNAMIC Tue Oct  8 11:37:28 UTC 2024 x86_64 x86_64 x86_64 GNU/Linux
# net.ipv4.tcp_available_congestion_control = reno bbr bbr1 cubic
# ('net.ipv4.tcp_available_congestion_control = reno bbr bbr1 cubic\n', '')

# %% [markdown]
# ### 3.4 Printing the Node SSH Commands

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    for node in slice.get_nodes():
        print(f"{node.get_name()}: {node.get_ssh_command()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# s1: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3040:f816:3eff:fe16:ce4
# s2: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3000:f816:3eff:fee9:dba0
# h1: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3040:f816:3eff:fe7a:e803
# h2: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3000:f816:3eff:feab:cef3

# %% [markdown]
# # Step 4 Configuring Nodes

# %% [markdown]
# ### 4.1 Configuring Updates and Packages

# %%
config_threads = {}

# %%
host_config_script = "sudo apt-get update -qq && sudo apt-get -y install && sudo apt-get -y install net-tools -qq && sudo apt-get -y install iperf3 -qq" 

try: 
    h1 = slice.get_node(name=h1_name)
    h1.execute("sudo sed -i '1s/.*/127.0.0.1 localhost h1/' /etc/hosts")
    if type(ip_address(h1.get_management_ip())) is IPv6Address:
        h1.execute("sudo sed -i '/nameserver/d' /etc/resolv.conf && sudo sh -c 'echo nameserver 2a00:1098:2c::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a01:4f8:c2c:123f::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a00:1098:2b::1 >> /etc/resolv.conf'")   
    h1_os_iface = h1.get_interface(network_name=net_h1_name)
    h1_os_iface.ip_addr_add(addr=h1_addr, subnet=h1_subnet)
    h1_config_thread = h1.execute_thread(host_config_script)
    config_threads[h1] = h1_config_thread
    
    h2 = slice.get_node(name=h2_name)
    h2.execute("sudo sed -i '1s/.*/127.0.0.1 localhost h2/' /etc/hosts")
    if type(ip_address(h2.get_management_ip())) is IPv6Address:
        h2.execute("sudo sed -i '/nameserver/d' /etc/resolv.conf && sudo sh -c 'echo nameserver 2a00:1098:2c::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a01:4f8:c2c:123f::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a00:1098:2b::1 >> /etc/resolv.conf'")
    h2_os_iface = h2.get_interface(network_name=net_h2_name)
    h2_os_iface.ip_addr_add(addr=h2_addr, subnet=h2_subnet)
    h2_config_thread = h2.execute_thread(host_config_script)
    config_threads[h2] = h2_config_thread

    s1 = slice.get_node(name=s1_name)  
    s1.execute("sudo sed -i '1s/.*/127.0.0.1 localhost s1/' /etc/hosts")
    if type(ip_address(s1.get_management_ip())) is IPv6Address:
        s1.execute("sudo sed -i '/nameserver/d' /etc/resolv.conf && sudo sh -c 'echo nameserver 2a00:1098:2c::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a01:4f8:c2c:123f::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a00:1098:2b::1 >> /etc/resolv.conf'")   
    s1_os_iface = s1.get_interface(network_name=net_h1_name)
    s1_os_iface.ip_addr_add(addr=s1_addr1, subnet=h1_subnet)
    s1_os_iface = s1.get_interface(network_name=net_s1_s2_name)
    s1_os_iface.ip_addr_add(addr=s1_addr2, subnet=s1_subnet)
    s1_config_thread = s1.execute_thread(host_config_script)
    config_threads[s1] = s1_config_thread

    s2 = slice.get_node(name=s2_name) 
    s2.execute("sudo sed -i '1s/.*/127.0.0.1 localhost s2/' /etc/hosts")
    if type(ip_address(s2.get_management_ip())) is IPv6Address:
        s2.execute("sudo sed -i '/nameserver/d' /etc/resolv.conf && sudo sh -c 'echo nameserver 2a00:1098:2c::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a01:4f8:c2c:123f::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a00:1098:2b::1 >> /etc/resolv.conf'")   
    s2_os_iface = s2.get_interface(network_name=net_h2_name)
    s2_os_iface.ip_addr_add(addr=s2_addr1, subnet=h2_subnet)   
    s2_os_iface = s2.get_interface(network_name=net_s1_s2_name)
    s2_os_iface.ip_addr_add(addr=s2_addr2, subnet=s2_subnet)
    s2_config_thread = s2.execute_thread(host_config_script)
    config_threads[s2] = s2_config_thread

except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc()

# %% [markdown]
# ### 4.2 Installing Mininet

# %%
h1.execute("git clone https://github.com/mininet/mininet  &> /dev/null")
h1.execute("cd mininet")
h1.execute("git checkout -b mininet-2.3.1b4")
h1.execute("cd ..")
h1.execute("mininet/util/install.sh -a &> /dev/null")

h2.execute("git clone https://github.com/mininet/mininet &> /dev/null")
h2.execute("cd mininet")
h2.execute("git checkout -b mininet-2.3.1b4")
h2.execute("cd ..")
h2.execute("mininet/util/install.sh -a &> /dev/null")
# Out:
#  fatal: not a git repository (or any of the parent directories): .git
#   fatal: not a git repository (or any of the parent directories): .git
# ('', '')

# %% [markdown]
# ### 4.3 Configuring Default Routes in h1 and h2 and Static Routes in S1 and S2

# %%
h1.execute("sudo ifconfig enp7s0 up")
h1.execute("sudo ip route add 172.17.0.0/16 via 172.16.255.254")
h2.execute("sudo ifconfig enp7s0 up")
h2.execute("sudo ip route add 172.16.0.0/16 via 172.17.255.254")

s1.execute("sudo sysctl -w net.ipv4.conf.all.forwarding=1")
s2.execute("sudo sysctl -w net.ipv4.conf.all.forwarding=1")

s1.execute("sudo ip route add 172.17.0.0/16 via 192.168.12.2")
s2.execute("sudo ip route add 172.16.0.0/16 via 192.168.12.1")
# Out:
# net.ipv4.conf.all.forwarding = 1
# net.ipv4.conf.all.forwarding = 1
# ('', '')

# %% [markdown]
# ### 4.3 Setting TCP Send and Receive Buffer Sizes in

# %%
h1.execute("sudo sysctl -w net.ipv4.tcp_wmem=\'1024 87380 200000000\'")
h1.execute("sudo sysctl -w net.ipv4.tcp_rmem=\'1024 87380 200000000\'")

h2.execute("sudo sysctl -w net.ipv4.tcp_wmem=\'1024 87380 200000000\'")
h1.execute("sudo sysctl -w net.ipv4.tcp_rmem=\'1024 87380 200000000\'")
# Out:
# net.ipv4.tcp_wmem = 1024 87380 200000000
# net.ipv4.tcp_rmem = 1024 87380 200000000
# net.ipv4.tcp_wmem = 1024 87380 200000000
# net.ipv4.tcp_rmem = 1024 87380 200000000
# ('net.ipv4.tcp_rmem = 1024 87380 200000000\n', '')

# %% [markdown]
# # Step 5 Misc Scripts

# %% [markdown]
# ### 5.1 Listing Available Sites

# %%
try:
    print(f"{fablib.list_sites()}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### 5.2 Printing Slice Attributes

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    print(f"{slice}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: Unable to find slice "bbr3_test" for this project. Check slice name spelling and project id.

# %% [markdown]
# ### 5.3 Printing the Node Attributes

# %%
try:
    slice = fablib.get_slice(name=slice_name)

    print(f"{slice.list_nodes()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: Unable to find slice "bbr3_test" for this project. Check slice name spelling and project id.

# %% [markdown]
# ### 5.4 Printing the Node Details

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    for node in slice.get_nodes():
        print(f"{node}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# ID                 f3e35fad-94ea-4070-a58c-f2579d54bf7d
# Name               s1
# Cores              2
# RAM                8
# Disk               100
# Image              default_ubuntu_22
# Image Type         qcow2
# Host               newy-w2.fabric-testbed.net
# Site               NEWY
# Management IP      2001:400:a100:3040:f816:3eff:fe2e:e3a6
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3040:f816:3eff:fe2e:e3a6
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# ID                 3ecb66da-972f-4c44-8752-0840625511bb
# Name               s2
# Cores              2
# RAM                8
# Disk               100
# Image              default_ubuntu_22
# Image Type         qcow2
# Host               salt-w1.fabric-testbed.net
# Site               SALT
# Management IP      2001:400:a100:3010:f816:3eff:fecf:be07
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3010:f816:3eff:fecf:be07
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# ID                 d71c7472-7b96-4945-b664-9de1af4c2c5c
# Name               h1
# Cores              2
# RAM                8
# Disk               100
# Image              default_ubuntu_22
# Image Type         qcow2
# Host               newy-w2.fabric-testbed.net
# Site               NEWY
# Management IP      2001:400:a100:3040:f816:3eff:fe86:802c
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3040:f816:3eff:fe86:802c
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# ID                 dfb1d1a3-b99e-4e10-a2a0-81aa983dfec3
# Name               h2
# Cores              2
# RAM                8
# Disk               100
# Image              default_ubuntu_22
# Image Type         qcow2
# Host               salt-w1.fabric-testbed.net
# Site               SALT
# Management IP      2001:400:a100:3010:f816:3eff:fe57:1c1a
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3010:f816:3eff:fe57:1c1a
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 5.5 Printing Interfaces

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    
    print(f"{slice.list_interfaces()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_da769 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_da769 th {
#   text-align: left;
# }
# #T_da769 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_da769 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_da769 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T
row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_da769_row2_col2" class="data row2 col2" >s2</td>
#       <td id="T_da769_row2_col3" class="data row2 col3" >net_s1_s2</td>
#       <td id="T_da769_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_da769_row2_col5" class="data row2 col5" >config</td>
#       <td id="T_da769_row2_col6" class="data row2 col6" ></td>
#       <td id="T_da769_row2_col7" class="data row2 col7" >06:D4:16:2C:10:10</td>
#       <td id="T_da769_row2_col8" class="data row2 col8" >enp8s0</td>
#       <td id="T_da769_row2_col9" class="data row2 col9" >enp8s0</td>
#       <td id="T_da769_row2_col10" class="data row2 col10" >192.168.12.2</td>
#       <td id="T_da769_row2_col11" class="data row2 col11" >6</td>
#       <td id="T_da769_row2_col12" class="data row2 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_da769_row3_col0" class="data row3 col0" >s2-s2_switch_nic1-p1</td>
#       <td id="T_da769_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_da769_row3_col2" class="data row3 col2" >s2</td>
#       <td id="T_da769_row3_col3" class="data row3 col3" >net_h2</td>
#       <td id="T_da769_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_da769_row3_col5" class="data row3 col5" >config</td>
#       <td id="T_da769_row3_col6" class="data row3 col6" ></td>
#       <td id="T_da769_row3_col7" class="data row3 col7" >06:C9:EE:46:AB:31</td>
#       <td id="T_da769_row3_col8" class="data row3 col8" >enp7s0</td>
#       <td id="T_da769_row3_col9" class="data row3 col9" >enp7s0</td>
#       <td id="T_da769_row3_col10" class="data row3 col10" >172.17.0.1</td>
#       <td id="T_da769_row3_col11" class="data row3 col11" >6</td>
#       <td id="T_da769_row3_col12" class="data row3 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_da769_row4_col0" class="data row4 col0" >h1-h1_nic-p1</td>
#       <td id="T_da769_row4_col1" class="data row4 col1" >p1</td>
#       <td id="T_da769_row4_col2" class="data row4 col2" >h1</td>
#       <td id="T_da769_row4_col3" class="data row4 col3" >net_h1</td>
#       <td id="T_da769_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_da769_row4_col5" class="data row4 col5" >config</td>
#       <td id="T_da769_row4_col6" class="data row4 col6" ></td>
#       <td id="T_da769_row4_col7" class="data row4 col7" >16:24:75:91:49:87</td>
#       <td id="T_da769_row4_col8" class="data row4 col8" >enp7s0</td>
#       <td id="T_da769_row4_col9" class="data row4 col9" >enp7s0</td>
#       <td id="T_da769_row4_col10" class="data row4 col10" >172.16.0.10</td>
#       <td id="T_da769_row4_col11" class="data row4 col11" >4</td>
#       <td id="T_da769_row4_col12" class="data row4 col12" >HundredGigE0/0/0/7</td>
#     </tr>
#     <tr>
#       <td id="T_da769_row5_col0" class="data row5 col0" >h
# <pandas.io.formats.style.Styler object at 0x7d9848349ed0>

# %% [markdown]
# ### 5.6 Deleting a Slice

# %%
slice.delete()

# %% [markdown]
# # 6 Inter-protocol Fairness

# %% [markdown]
# ## 6.1 Pre-test Configuration

# %% [markdown]
# ### 6.1.1 Launching Mininet Topology in h1 and h2

# %%
#h1 = slice.get_node(name=h1_name)
#h2 = slice.get_node(name=h2_name)
num_hosts=1024

h1.upload_file('scripts/topo_h1.py', 'topo_h1.py')
h2.upload_file('scripts/topo_h2.py', 'topo_h2.py')

#h1.execute('sudo mn -c &> /dev/null')
#h2.execute('sudo mn -c &> /dev/null')

h1.execute('mkdir results')
h2.execute('mkdir results')

# h1.execute(f'sudo python3 topo_h1.py {num_hosts} &')
# h2.execute(f'sudo python3 topo_h2.py {num_hosts} &')
# Out:
#  mkdir: cannot create directory ‘results’: File exists
#   mkdir: cannot create directory ‘results’: File exists
# ('', 'mkdir: cannot create directory ‘results’: File exists\n')

# %% [markdown]
# ### !!!Run the scripts manually in the VMS

# %%
print(f"Run the following command on h1: sudo python3 topo_h1.py {num_hosts}")
print(f"Run the following command on h2: sudo python3 topo_h2.py {num_hosts}")
# Out:
# Run the following command on h1: sudo python3 topo_h1.py 1024
# Run the following command on h2: sudo python3 topo_h2.py 1024

# %% [markdown]
# ### 6.1.2 Adding the VM's Port to Switch S1

# %%
h1.execute('sudo ovs-vsctl add-port s_agg1 enp7s0')
h2.execute('sudo ovs-vsctl add-port s_agg2 enp7s0')
# Out:
#  ovs-vsctl: cannot create a port named enp7s0 because a port named enp7s0 already exists on bridge s_agg2
# ('',
#  'ovs-vsctl: cannot create a port named enp7s0 because a port named enp7s0 already exists on bridge s_agg2\n')

# %% [markdown]
# ### 6.1.3 Configure static Routes in the Mininet hosts

# %%
for i in range(1, num_hosts + 1):
    print(f"Setting default route on host hs{i} and hr{i}")
    h1.execute(f"mininet/util/m hs{i} route add default gw 172.16.255.254 &")
    h2.execute(f"mininet/util/m hr{i} route add default gw 172.17.255.254 &")
# Out:
# Setting default route on host hs1 and hr1
# ERROR! Session/line number was not unique in database. History logging moved to new session 2
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs2 and hr2
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs3 and hr3
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs4 and hr4
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs5 and hr5
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs6 and hr6
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs7 and hr7
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs8 and hr8
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs9 and hr9
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs10 and hr10
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs11 and hr11
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs12 and hr12
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs13 and hr13
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs14 and hr14
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs15 and hr15
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs16 and hr16
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs17 and hr17
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs18 and hr18
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs19 and hr19
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs20 and hr20
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs21 and hr21
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs22 and hr22
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs23 and hr23
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs24 and hr24
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs25 and hr25
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs26 and hr26
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs27 and hr27
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs28 and hr28
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs29 and hr29
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs30 and hr30
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs31 and hr31
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs32 and hr32
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs33 and hr33
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs34 and hr34
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs35 and hr35
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs36 and hr36
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs37 and hr37
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs38 and hr38
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs39 and hr39
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs40 and hr40
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs41 and hr41
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs42 and hr42
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs43 and hr43
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs44 and hr44
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs45 and hr45
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs46 and hr46
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs47 and hr47
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs48 and hr48
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs49 and hr49
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs50 and hr50
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs51 and hr51
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs52 and hr52
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs53 and hr53
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs54 and hr54
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs55 and hr55
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs56 and hr56
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs57 and hr57
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs58 and hr58
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs59 and hr59
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs60 and hr60
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs61 and hr61
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs62 and hr62
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs63 and hr63
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs64 and hr64
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs65 and hr65
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs66 and hr66
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs67 and hr67
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs68 and hr68
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs69 and hr69
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs70 and hr70
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs71 and hr71
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs72 and hr72
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs73 and hr73
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs74 and hr74
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host h
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1014 and hr1014
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1015 and hr1015
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1016 and hr1016
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1017 and hr1017
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1018 and hr1018
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1019 and hr1019
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1020 and hr1020
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1021 and hr1021
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1022 and hr1022
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1023 and hr1023
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists
#  Setting default route on host hs1024 and hr1024
#  SIOCADDRT: File exists
#   SIOCADDRT: File exists

# %% [markdown]
# ### 6.1.4 Populating the ARP tables in the Mininet Hosts

# %%
for i in range(1, num_hosts + 1):
    h1.execute_thread(f"mininet/util/m hs{i} ping 172.17.0.{i} -c 1", quiet=True)
    h2.execute_thread(f"mininet/util/m hr{i} ping 172.16.0.{i} -c 1", quiet=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 for i in range(1, num_hosts + 1):
# ----> 2     h1.execute_thread(f"mininet/util/m hs{i} ping 172.17.0.{i} -c 1", quiet=True)
#       3     h2.execute_thread(f"mininet/util/m hr{i} ping 172.16.0.{i} -c 1", quiet=True)
#
# TypeError: Node.execute_thread() got an unexpected keyword argument 'quiet'

# %% [markdown]
# ### 6.1.4 Starting the iPerf3 Servers in h2

# %%
for i in range(1, num_hosts + 1):
    print(f"Starting iperf3 server on host hr{i}")
    h2.execute_thread(f"mininet/util/m hr{i} iperf3 -s")
# Out:
# Starting iperf3 server on host hr1
# Starting iperf3 server on host hr2
# Starting iperf3 server on host hr3
# Starting iperf3 server on host hr4
# Starting iperf3 server on host hr5
# Starting iperf3 server on host hr6
# Starting iperf3 server on host hr7
# Starting iperf3 server on host hr8
# Starting iperf3 server on host hr9
# Starting iperf3 server on host hr10
# Starting iperf3 server on host hr11
# Starting iperf3 server on host hr12
# Starting iperf3 server on host hr13
# Starting iperf3 server on host hr14
# Starting iperf3 server on host hr15
# Starting iperf3 server on host hr16
# Starting iperf3 server on host hr17
# Starting iperf3 server on host hr18
# Starting iperf3 server on host hr19
# Starting iperf3 server on host hr20
# Starting iperf3 server on host hr21
# Starting iperf3 server on host hr22
# Starting iperf3 server on host hr23
# Starting iperf3 server on host hr24
# Starting iperf3 server on host hr25
# Starting iperf3 server on host hr26
# Starting iperf3 server on host hr27
# Starting iperf3 server on host hr28
# Starting iperf3 server on host hr29
# Starting iperf3 server on host hr30
# Starting iperf3 server on host hr31
# Starting iperf3 server on host hr32
# Starting iperf3 server on host hr33
# Starting iperf3 server on host hr34
# Starting iperf3 server on host hr35
# Starting iperf3 server on host hr36
# Starting iperf3 server on host hr37
# Starting iperf3 server on host hr38
# Starting iperf3 server on host hr39
# Starting iperf3 server on host hr40
# Starting iperf3 server on host hr41
# Starting iperf3 server on host hr42
# Starting iperf3 server on host hr43
# Starting iperf3 server on host hr44
# Starting iperf3 server on host hr45
# Starting iperf3 server on host hr46
# Starting iperf3 server on host hr47
# Starting iperf3 server on host hr48
# Starting iperf3 server on host hr49
# Starting iperf3 server on host hr50
# Starting iperf3 server on host hr51
# Starting iperf3 server on host hr52
# Starting iperf3 server on host hr53
# Starting iperf3 server on host hr54
# Starting iperf3 server on host hr55
# Starting iperf3 server on host hr56
# Starting iperf3 server on host hr57
# Starting iperf3 server on host hr58
# Starting iperf3 server on host hr59
# Starting iperf3 server on host hr60
# Starting iperf3 server on host hr61
# Starting iperf3 server on host hr62
# Starting iperf3 server on host hr63
# Starting iperf3 server on host hr64
# Starting iperf3 server on host hr65
# Starting iperf3 server on host hr66
# Starting iperf3 server on host hr67
# Starting iperf3 server on host hr68
# Starting iperf3 server on host hr69
# Starting iperf3 server on host hr70
# Starting iperf3 server on host hr71
# Starting iperf3 server on host hr72
# Starting iperf3 server on host hr73
# Starting iperf3 server on host hr74
# Starting iperf3 server on host hr75
# Starting iperf3 server on host hr76
# Starting iperf3 server on host hr77
# Starting iperf3 server on host hr78
# Starting iperf3 server on host hr79
# Starting iperf3 server on host hr80
# Starting iperf3 server on host hr81
# Starting iperf3 server on host hr82
# Starting iperf3 server on host hr83
# Starting iperf3 server on host hr84
# Starting iperf3 server on host hr85
# Starting iperf3 server on host hr86
# Starting iperf3 server on host hr87
# Starting iperf3 server on host hr88
# Starting iperf3 server on host hr89
# Starting iperf3 server on host hr90
# Starting iperf3 server on host hr91
# Starting iperf3 server on host hr92
# Starting iperf3 server on host hr93
# Starting iperf3 server on host hr94
# Starting iperf3 server on host hr95
# Starting iperf3 server on host hr96
# Starting iperf3 server on host hr97
# Starting iperf3 server on host hr98
# Starting iperf3 server on host hr99
# Starting iperf3 server on host hr100
# Starting iperf3 server on host hr101
# Starting iperf3 server on host hr102
# Starting iperf3 server on host hr103
# Starting iperf3 server on host hr104
# Starting iperf3 server on host hr105
# Starting iperf3 server on host hr106
# Starting iperf3 server on host hr107
# Starting iperf3 server on host hr108
# Starting iperf3 server on host hr109
# Starting iperf3 server on host hr110
# Starting iperf3 server on host hr111
# Starting iperf3 server on host hr112
# Starting iperf3 server on host hr113
# Starting iperf3 server on host hr114
# Starting iperf3 server on host hr115
# Starting iperf3 server on host hr116
# Starting iperf3 server on host hr117
# Starting iperf3 server on host hr118
# Starting iperf3 server on host hr119
# Starting iperf3 server on host hr120
# Starting iperf3 server on host hr121
# Starting iperf3 server on host hr122
# Starting iperf3 server on host hr123
# Starting iperf3 server on host hr124
# Starting iperf3 server on host hr125
# Starting iperf3 server on host hr126
# Starting iperf3 server on host hr127
# Starting iperf3 server on host hr128
# Starting iperf3 server on host hr129
# Starting iperf3 server on host hr130
# Starting iperf3 server on host hr131
# Starting iperf3 server on host hr132
# Starting iperf3 server on host hr133
# Starting iperf3 server on host hr134
# Starting iperf3 server on host hr135
# Starting iperf3 server on host hr136
# Starting iperf3 server on host hr137
# Starting iperf3 server on host hr138
# Starting iperf3 server on host hr139
# Starting iperf3 server on host hr140
# Starting iperf3 server on host hr141
# Starting iperf3 server on host hr142
# Starting iperf3 server on host hr143
# Starting iperf3 server on host hr144
# Starting iperf3 server on host hr145
# Starting iperf3 server on host hr146
# Starting iperf3 server on host hr147
# Starting iperf3 server on host hr148
# Starting iperf3 server on host hr149
# Starting iperf3 server on host hr150
# Starting iperf3 server on host hr151
# Starting iperf3 server on host hr152
# Starting iperf3 server on host hr153
# Starting iperf3 server on host hr154
# Starting iperf3 server on host hr155
# Starting iperf3 server on host hr156
# Starting iperf3 server on host hr157
# Starting iperf3 server on host hr158
# Starting iperf3 server on host hr159
# Starting iperf3 server on host hr160
# Starting iperf3 server on host hr161
# Starting iperf3 server on host hr162
# Starting iperf3 server on host hr163
# Starting iperf3 server on host hr164
# Starting iperf3 server on host hr165
# Starting iperf3 server on host hr166
# Starting iperf3 server on host hr167
# Starting iperf3 server on host hr168
# Starting iperf3 server on host hr169
# Starting iperf3 server on host hr170
# Starting iperf3 server on host hr171
# Starting iperf3 server on host hr172
# Starting iperf3 server on host hr173
# Starting iperf3 server on host hr174
# Starting iperf3 server on host hr175
# Starting iperf3 server on host hr176
# Starting iperf3 server on host hr177
# Starting iperf3 server on host hr178
# Starting iperf3 server on host hr179
# Starting iperf3 server on host hr180
# Starting iperf3 server on host hr181
# Starting iperf3 server on host hr182
# Starting iperf3 server on host hr183
# Starting iperf3 server on host hr184
# Starting iperf3 server on host hr185
# Starting iperf3 server on host hr186
# Starting iperf3 server on host hr187
# Starting iperf3 server on host hr188
# Starting iperf3 server on host hr189
# Starting iperf3 server on host hr190
# Starting iperf3 server on host hr191
# Starting iperf3 server on host hr192
# Starting iperf3 server on host hr193
# Starting iperf3 server on host hr194
# Starting iperf3 server on host hr195
# Starting iperf3 server on host hr196
# Starting iperf3 server on host hr197
# Starting iperf3 server on host hr198
# Starting iperf3 server on host hr199
# Starting iperf3 server on host hr200
# Starting iperf3 server on host hr201
# Starting iperf3 server on host hr202
# Starting iperf3 server on host hr203
# Starting iperf3 server on host hr204
# Starting iperf3 server on host hr205
# Starting iperf3 server on host hr206
# Starting iperf3 server on host hr207
# Starting iperf3 server on host hr208
# Starting iperf3 server on host hr209
# Starting iperf3 server on host hr210
# Starting iperf3 server on host hr211
# Starting iperf3 server on host hr212
# Starting iperf3 server on host hr213
# Starting iperf3 server on host hr214
# Starting iperf3 server on host hr215
# Starting iperf3 server on host hr216
# Starting iperf3 server on host hr217
# Starting iperf3 server on host hr218
# Starting iperf3 server on host hr219
# Starting iperf3 server on host hr220
# Starting iperf3 server on host hr221
# Starting iperf3 server on host hr222
# Starting iperf3 server on host hr223
# Starting iperf3 server on host hr224
# Starting iperf3 server on host hr225
# Starting iperf3 server on host hr226
# Starting iperf3 server on host hr227
# Starting iperf3 server on host hr228
# Starting iperf3 server on host hr229
# Starting iperf3 server on host hr230
# Starting iperf3 server on host hr231
# Starting iperf3 server on host hr232
# Starting iperf3 server on host hr233
# Starting iperf3 server on host hr234
# Starting iperf3 server on host hr235
# Starting iperf3 server on host hr236
# Starting iperf3 server on host hr237
# Starting iperf3 server on host hr238
# Starting iperf3 server on host hr239
# Starting iperf3 server on host hr240
# Starting iperf3 server on host hr241
# Starting iperf3 server on host hr242
# Starting iperf3 server on host hr243
# Starting iperf3 server on host hr244
# Starting iperf3 server on host hr245
# Starting iperf3 server on host hr246
# Starting iperf3 server on host hr247
# Starting iperf3 server on host hr248
# Starting iperf3 server on host hr249
# Starting iperf3 server on host hr250
# Starting iperf3 server on host hr251
# Starting iperf3 server on host hr252
# Starting iperf3 server on host hr253
# Starting iperf3 server on host hr254
# Starting iperf3 server on host hr255
# Starting iperf3 server on host hr256
# Starting iperf3 server on host hr257
# Starting iperf3 server on host hr258
# Starting iperf3 server on host hr259
# Starting iperf3 server on host hr260
# Starting iperf3 server on host hr261
# Starting iperf3 server on host hr262
# Starting iperf3 server on host hr263
# Starting iperf3 server on host hr264
# Starting iperf3 server on host hr265
# Starting iperf3 server on host hr266
# Starting iperf3 server on host hr267
# Starting iperf3 server on host hr268
# Starting iperf3 server on host hr269
# Starting iperf3 server on host hr270
# Starting iperf3 server on host hr271
# Starting iperf3 server on host hr272
# Starting iperf3 server on host hr273
# Starting iperf3 server on host hr274
# Starting iperf3 server on host hr275
# Starting iperf3 server on host hr276
# Starting iperf3 server on host hr277
# Starting iperf3 server on host hr278
# Starting iperf3 server on host hr279
# Starting iperf3 server on host hr280
# Starting iperf3 server on host hr281
# Starting iperf3 server on host hr282
# Starting iperf3 server on host hr283
# Starting iperf3 server on host hr284
# Starting iperf3 server on host hr285
# Starting iperf3 server on host hr286
# Starting iperf3 server on host hr287
# Starting iperf3 server on host hr288
# Starting iperf3 server on host hr289
# Starting iperf3 server on host hr290
# Starting iperf3 server on host hr291
# Starting iperf3 server on host hr292
# Starting iperf3 server on host hr293
# Starting iperf3 server on host hr294
# Starting iperf3 server on host hr295
# Starting iperf3 server on host hr296
# Starting iperf3 server on host hr297
# Starting iperf3 server on host hr298
# Starting iperf3 server on host hr299
# Starting iperf3 server on host hr300
# Starting iperf3 server on host hr301
# Starting iperf3 server on host hr302
# Starting iperf3 server on host hr303
# Starting iperf3 server on host hr304
# Starting iperf3 server on host hr305
# Starting iperf3 server on host hr306
# Starting iperf3 server on host hr307
# Starting iperf3 server on host hr308
# Starting iperf3 server on host hr309
# Starting iperf3 server on host hr310
# Starting iperf3 server on host hr311
# Starting iperf3 server on host hr312
# Starting iperf3 server on host hr313
# Starting iperf3 server on host hr314
# Starting iperf3 server on host hr315
# Starting iperf3 server on host hr316
# Starting iperf3 server on host hr317
# Starting iperf3 server on host hr318
# Starting iperf3 server on host hr319
# Starting iperf3 server on host hr320
# Starting iperf3 server on host hr321
# Starting iperf3 server on host hr322
# Starting iperf3 server on host hr323
# Starting iperf3 server on host hr324
# Starting iperf3 server on host hr325
# Starting iperf3 server on host hr326
# Starting iperf3 server on host hr327
# Starting iperf3 server on host hr328
# Starting iperf3 server on host hr329
# Starting iperf3 server on host hr330
# Starting iperf3 server on host hr331
# Starting iperf3 server on host hr332
# Starting iperf3 server on host hr333
# Starting iperf3 server on host hr334
# Starting iperf3 server on host hr335
# Starting iperf3 server on host hr336
# Starting iperf3 server on host hr337
# Starting iperf3 server on host hr338
# Starting iperf3 server on host hr339
# Starting iperf3 server on host hr340
# Starting iperf3 server on host hr341
# Starting iperf3 server on host hr342
# Starting iperf3 server on host hr343
# Starting iperf3 server on host hr344
# Starting iperf3 server on host hr345
# Starting iperf3 server on host hr346
# Starting iperf3 server on host hr347
# Starting iperf3 server on host hr348
# Starting iperf3 server on host hr349
# Starting iperf3 server on host hr350
# Starting iperf3 server on host hr351
# Starting iperf3 server on host hr352
# Starting iperf3 server on host hr353
# Starting iperf3 server on host hr354
# Starting iperf3 server on host hr355
# Starting iperf3 server on host hr356
# Starting iperf3 server on host hr357
# Starting iperf3 server on host hr358
# Starting iperf3 server on host hr359
# Starting iperf3 server on host hr360
# Starting iperf3 server on host hr361
# Starting iperf3 server on host hr362
# Starting iperf3 server on host hr363
# Starting iperf3 server on host hr364
# Starting iperf3 server on host hr365
# Starting iperf3 server on host hr366
# Starting iperf3 server on host hr367
# Starting iperf3 server on host hr368
# Starting iperf3 server on host hr369
# Starting iperf3 server on host hr370
# Starting iperf3 server on host hr371
# Starting iperf3 server on host hr372
# Starting iperf3 server on host hr373
# Starting iperf3 server on host hr374
# Starting iperf3 server on host hr375
# Starting iperf3 server on host hr376
# Starting iperf3 server on host hr377
# Starting iperf3 server on host hr378
# Starting iperf3 server on host hr379
# Starting iperf3 server on host hr380
# Starting iperf3 server on host hr381
# Starting iperf3 server on host hr382
# Starting iperf3 server on host hr383
# Starting iperf3 server on host hr384
# Starting iperf3 server on host hr385
# Starting iperf3 server on host hr386
# Starting iperf3 server on host hr387
# Starting iperf3 server on host hr388
# Starting iperf3 server on host hr389
# Starting iperf3 server on host hr390
# Starting iperf3 server on host hr391
# Starting iperf3 server on host hr392
# Starting iperf3 server on host hr393
# Starting iperf3 server on host hr394
# Starting iperf3 server on host hr395
# Starting iperf3 server on host hr396
# Starting iperf3 server on host hr397
# Starting iperf3 server on host hr398
# Starting iperf3 server on host hr399
# Starting iperf3 server on host hr400
# Starting iperf3 server on host hr401
# Starting iperf3 server on host hr402
# Starting iperf3 server on host hr403
# Starting iperf3 server on host hr404
# Starting iperf3 server on host hr405
# Starting iperf3 server on host hr406
# Starting iperf3 server on host hr407
# Starting iperf3 server on host hr408
# Starting iperf3 server on host hr409
# Starting iperf3 server on host hr410
# Starting iperf3 server on host hr411
# Starting iperf3 server on host hr412
# Starting iperf3 server on host hr413
# Starting iperf3 server on host hr414
# Starting iperf3 server on host hr415
# Starting iperf3 server on host hr416
# Starting iperf3 server on host hr417
# Starting iperf3 server on host hr418
# Starting iperf3 server on host hr419
# Starting iperf3 server on host hr420
# Starting iperf3 server on host hr421
# Starting iperf3 server on host hr422
# Starting iperf3 server on host hr423
# Starting iperf3 server on host hr424
# Starting iperf3 server on host hr425
# Starting iperf3 server on host hr426
# Starting iperf3 server on host hr427
# Starting iperf3 server on host hr428
# Starting iperf3 server on host hr429
# Starting iperf3 server on host hr430
# Starting iperf3 server on host hr431
# Starting iperf3 server on host hr432
# Starting iperf3 server on host hr433
# Starting iperf3 server on host hr434
# Starting iperf3 server on host hr435
# Starting iperf3 server on host hr436
# Starting iperf3 server on host hr437
# Starting iperf3 server on host hr438
# Starting iperf3 server on host hr439
# Starting iperf3 server on host hr440
# Starting iperf3 server on host hr441
# Starting iperf3 server on host hr442
# Starting iperf3 server on host hr443
# Starting iperf3 server on host hr444
# Starting iperf3 server on host hr445
# Starting iperf3 server on host hr446
# Starting iperf3 server on host hr447
# Starting iperf3 server on host hr448
# Starting iperf3 server on host hr449
# Starting iperf3 server on host hr450
# Starting iperf3 server on host hr451
# Starting iperf3 server on host hr452
# Starting iperf3 server on host hr453
# Starting iperf3 server on host hr454
# Starting iperf3 server on host hr455
# Starting iperf3 server on host hr456
# Starting iperf3 server on host hr457
# Starting iperf3 server on host hr458
# Starting iperf3 server on host hr459
# Starting iperf3 server on host hr460
# Starting iperf3 server on host hr461
# Starting iperf3 server on host hr462
# Starting iperf3 server on host hr463
# Starting iperf3 server on host hr464
# Starting iperf3 server on host hr465
# Starting iperf3 server on host hr466
# Starting iperf3 server on host hr467
# Starting iperf3 server on host hr468
# Starting iperf3 server on host hr469
# Starting iperf3 server on host hr470
# Starting iperf3 server on host hr471
# Starting iperf3 server on host hr472
# Starting iperf3 server on host hr473
# Starting iperf3 server on host hr474
# Starting iperf3 server on host hr475
# Starting iperf3 server on host hr476
# Starting iperf3 server on host hr477
# Starting iperf3 server on host hr478
# Starting iperf3 server on host hr479
# Starting iperf3 server on host hr480
# Starting iperf3 server on host hr481
# Starting iperf3 server on host hr482
# Starting iperf3 server on host hr483
# Starting iperf3 server on host hr484
# Starting iperf3 server on host hr485
# Starting iperf3 server on host hr486
# Starting iperf3 server on host hr487
# Starting iperf3 server on host hr488
# Starting iperf3 server on host hr489
# Starting iperf3 server on host hr490
# Starting iperf3 server on host hr491
# Starting iperf3 server on host hr492
# Starting iperf3 server on host hr493
# Starting iperf3 server on host hr494
# Starting iperf3 server on host hr495
# Starting iperf3 server on host hr496
# Starting iperf3 server on host hr497
# Starting iperf3 server on host hr498
# Starting iperf3 server on host hr499
# Starting iperf3 server on host hr500
# Starting iperf3 server on host hr501
# Starting iperf3 server on host hr502
# Starting iperf3 server on host hr503
# Starting iperf3 server on host hr504
# Starting iperf3 server on host hr505
# Starting iperf3 server on host hr506
# Starting iperf3 server on host hr507
# Starting iperf3 server on host hr508
# Starting iperf3 server on host hr509
# Starting iperf3 server on host hr510
# Starting iperf3 server on host hr511
# Starting iperf3 server on host hr512
# Starting iperf3 server on host hr513
# Starting iperf3 server on host hr514
# Starting iperf3 server on host hr515
# Starting iperf3 server on host hr516
# Starting iperf3 server on host hr517
# Starting iperf3 server on host hr518
# Starting iperf3 server on host hr519
# Starting iperf3 server on host hr520
# Starting iperf3 server on host hr521
# Starting iperf3 server on host hr522
# Starting iperf3 server on host hr523
# Starting iperf3 server on host hr524
# Starting iperf3 server on host hr525
# Starting iperf3 server on host hr526
# Starting iperf3 server on host hr527
# Starting iperf3 server on host hr528
# Starting iperf3 server on host hr529
# Starting iperf3 server on host hr530
# Starting iperf3 server on host hr531
# Starting iperf3 server on host hr532
# Starting iperf3 server on host hr533
# Starting iperf3 server on host hr534
# Starting iperf3 server on host hr535
# Starting iperf3 server on host hr536
# Starting iperf3 server on host hr537
# Starting iperf3 server on host hr538
# Starting iperf3 server on host hr539
# Starting iperf3 server on host hr540
# Starting iperf3 server on host hr541
# Starting iperf3 server on host hr542
# Starting iperf3 server on host hr543
# Starting iperf3 server on host hr544
# Starting iperf3 server on host hr545
# Starting iperf3 server on host hr546
# Starting iperf3 server on host hr547
# Starting iperf3 server on host hr548
# Starting iperf3 server on host hr549
# Starting iperf3 server on host hr550
# Starting iperf3 server on host hr551
# Starting iperf3 server on host hr552
# Starting iperf3 server on host hr553
# Starting iperf3 server on host hr554
# Starting iperf3 server on host hr555
# Starting iperf3 server on host hr556
# Starting iperf3 server on host hr557
# Starting iperf3 server on host hr558
# Starting iperf3 server on host hr559
# Starting iperf3 server on host hr560
# Starting iperf3 server on host hr561
# Starting iperf3 server on host hr562
# Starting iperf3 server on host hr563
# Starting iperf3 server on host hr564
# Starting iperf3 server on host hr565
# Starting iperf3 server on host hr566
# Starting iperf3 server on host hr567
# Starting iperf3 server on host hr568
# Starting iperf3 server on host hr569
# Starting iperf3 server on host hr570
# Starting iperf3 server on host hr571
# Starting iperf3 server on host hr572
# Starting iperf3 server on host hr573
# Starting iperf3 server on host hr574
# Starting iperf3 server on host hr575
# Starting iperf3 server on host hr576
# Starting iperf3 server on host hr577
# Starting iperf3 server on host hr578
# Starting iperf3 server on host hr579
# Starting iperf3 server on host hr580
# Starting iperf3 server on host hr581
# Starting iperf3 server on host hr582
# Starting iperf3 server on host hr583
# Starting iperf3 server on host hr584
# Starting iperf3 server on host hr585
# Starting iperf3 server on host hr586
# Starting iperf3 server on host hr587
# Starting iperf3 server on host hr588
# Starting iperf3 server on host hr589
# Starting iperf3 server on host hr590
# Starting iperf3 server on host hr591
# Starting iperf3 server on host hr592
# Starting iperf3 server on host hr593
# Starting iperf3 server on host hr594
# Starting iperf3 server on host hr595
# Starting iperf3 server on host hr596
# Starting iperf3 server on host hr597
# Starting iperf3 server on host hr598
# Starting iperf3 server on host hr599
# Starting iperf3 server on host hr600
# Starting iperf3 server on host hr601
# Starting iperf3 server on host hr602
# Starting iperf3 server on host hr603
# Starting iperf3 server on host hr604
# Starting iperf3 server on host hr605
# Starting iperf3 server on host hr606
# Starting iperf3 server on host hr607
# Starting iperf3 server on host hr608
# Starting iperf3 server on host hr609
# Starting iperf3 server on host hr610
# Starting iperf3 server on host hr611
# Starting iperf3 server on host hr612
# Starting iperf3 server on host hr613
# Starting iperf3 server on host hr614
# Starting iperf3 server on host hr615
# Starting iperf3 server on host hr616
# Starting iperf3 server on host hr617
# Starting iperf3 server on host hr618
# Starting iperf3 server on host hr619
# Starting iperf3 server on host hr620
# Starting iperf3 server on host hr621
# Starting iperf3 server on host hr622
# Starting iperf3 server on host hr623
# Starting iperf3 server on host hr624
# Starting iperf3 server on host hr625
# Starting iperf3 server on host hr626
# Starting iperf3 server on host hr627
# Starting iperf3 server on host hr628
# Starting iperf3 server on host hr629
# Starting iperf3 server on host hr630
# Starting iperf3 server on host hr631
# Starting iperf3 server on host hr632
# Starting iperf3 server on host hr633
# Starting iperf3 server on host hr634
# Starting iperf3 server on host hr635
# Starting iperf3 server on host hr636
# Starting iperf3 server on host hr637
# Starting iperf3 server on host hr638
# Starting iperf3 server on host hr639
# Starting iperf3 server on host hr640
# Starting iperf3 server on host hr641
# Starting iperf3 server on host hr642
# Starting iperf3 server on host hr643
# Starting iperf3 server on host hr644
# Starting iperf3 server on host hr645
# Starting iperf3 server on host hr646
# Starting iperf3 server on host hr647
# Starting iperf3 server on host hr648
# Starting iperf3 server on host hr649
# Starting iperf3 server on host hr650
# Starting iperf3 server on host hr651
# Starting iperf3 server on host hr652
# Starting iperf3 server on host hr653
# Starting iperf3 server on host hr654
# Starting iperf3 server on host hr655
# Starting iperf3 server on host hr656
# Starting iperf3 server on host hr657
# Starting iperf3 server on host hr658
# Starting iperf3 server on host hr659
# Starting iperf3 server on host hr660
# Starting iperf3 server on host hr661
# Starting iperf3 server on host hr662
# Starting iperf3 server on host hr663
# Starting iperf3 server on host hr664
# Starting iperf3 server on host hr665
# Starting iperf3 server on host hr666
# Starting iperf3 server on host hr667
# Starting iperf3 server on host hr668
# Starting iperf3 server on host hr669
# Starting iperf3 server on host hr670
# Starting iperf3 server on host hr671
# Starting iperf3 server on host hr672
# Starting iperf3 server on host hr673
# Starting iperf3 server on host hr674
# Starting iperf3 server on host hr675
# Starting iperf3 server on host hr676
# Starting iperf3 server on host hr677
# Starting iperf3 server on host hr678
# Starting iperf3 server on host hr679
# Starting iperf3 server on host hr680
# Starting iperf3 server on host hr681
# Starting iperf3 server on host hr682
# Starting iperf3 server on host hr683
# Starting iperf3 server on host hr684
# Starting iperf3 server on host hr685
# Starting iperf3 server on host hr686
# Starting iperf3 server on host hr687
# Starting iperf3 server on host hr688
# Starting iperf3 server on host hr689
# Starting iperf3 server on host hr690
# Starting iperf3 server on host hr691
# Starting iperf3 server on host hr692
# Starting iperf3 server on host hr693
# Starting iperf3 server on host hr694
# Starting iperf3 server on host hr695
# Starting iperf3 server on host hr696
# Starting iperf3 server on host hr697
# Starting iperf3 server on host hr698
# Starting iperf3 server on host hr699
# Starting iperf3 server on host hr700
# Starting iperf3 server on host hr701
# Starting iperf3 server on host hr702
# Starting iperf3 server on host hr703
# Starting iperf3 server on host hr704
# Starting iperf3 server on host hr705
# Starting iperf3 server on host hr706
# Starting iperf3 server on host hr707
# Starting iperf3 server on host hr708
# Starting iperf3 server on host hr709
# Starting iperf3 server on host hr710
# Starting iperf3 server on host hr711
# Starting iperf3 server on host hr712
# Starting iperf3 server on host hr713
# Starting iperf3 server on host hr714
# Starting iperf3 server on host hr715
# Starting iperf3 server on host hr716
# Starting iperf3 server on host hr717
# Starting iperf3 server on host hr718
# Starting iperf3 server on host hr719
# Starting iperf3 server on host hr720
# Starting iperf3 server on host hr721
# Starting iperf3 server on host hr722
# Starting iperf3 server on host hr723
# Starting iperf3 server on host hr724
# Starting iperf3 server on host hr725
# Starting iperf3 server on host hr726
# Starting iperf3 server on host hr727
# Starting iperf3 server on host hr728
# Starting iperf3 server on host hr729
# Starting iperf3 server on host hr730
# Starting iperf3 server on host hr731
# Starting iperf3 server on host hr732
# Starting iperf3 server on host hr733
# Starting iperf3 server on host hr734
# Starting iperf3 server on host hr735
# Starting iperf3 server on host hr736
# Starting iperf3 server on host hr737
# Starting iperf3 server on host hr738
# Starting iperf3 server on host hr739
# Starting iperf3 server on host hr740
# Starting iperf3 server on host hr741
# Starting iperf3 server on host hr742
# Starting iperf3 server on host hr743
# Starting iperf3 server on host hr744
# Starting iperf3 server on host hr745
# Starting iperf3 server on host hr746
# Starting iperf3 server on host hr747
# Starting iperf3 server on host hr748
# Starting iperf3 server on host hr749
# Starting iperf3 server on host hr750
# Starting iperf3 server on host hr751
# Starting iperf3 server on host hr752
# Starting iperf3 server on host hr753
# Starting iperf3 server on host hr754
# Starting iperf3 server on host hr755
# Starting iperf3 server on host hr756
# Starting iperf3 server on host hr757
# Starting iperf3 server on host hr758
# Starting iperf3 server on host hr759
# Starting iperf3 server on host hr760
# Starting iperf3 server on host hr761
# Starting iperf3 server on host hr762
# Starting iperf3 server on host hr763
# Starting iperf3 server on host hr764
# Starting iperf3 server on host hr765
# Starting iperf3 server on host hr766
# Starting iperf3 server on host hr767
# Starting iperf3 server on host hr768
# Starting iperf3 server on host hr769
# Starting iperf3 server on host hr770
# Starting iperf3 server on host hr771
# Starting iperf3 server on host hr772
# Starting iperf3 server on host hr773
# Starting iperf3 server on host hr774
# Starting iperf3 server on host hr775
# Starting iperf3 server on host hr776
# Starting iperf3 server on host hr777
# Starting iperf3 server on host hr778
# Starting iperf3 server on host hr779
# Starting iperf3 server on host hr780
# Starting iperf3 server on host hr781
# Starting iperf3 server on host hr782
# Starting iperf3 server on host hr783
# Starting iperf3 server on host hr784
# Starting iperf3 server on host hr785
# Starting iperf3 server on host hr786
# Starting iperf3 server on host hr787
# Starting iperf3 server on host hr788
# Starting iperf3 server on host hr789
# Starting iperf3 server on host hr790
# Starting iperf3 server on host hr791
# Starting iperf3 server on host hr792
# Starting iperf3 server on host hr793
# Starting iperf3 server on host hr794
# Starting iperf3 server on host hr795
# Starting iperf3 server on host hr796
# Starting iperf3 server on host hr797
# Starting iperf3 server on host hr798
# Starting iperf3 server on host hr799
# Starting iperf3 server on host hr800
# Starting iperf3 server on host hr801
# Starting iperf3 server on host hr802
# Starting iperf3 server on host hr803
# Starting iperf3 server on host hr804
# Starting iperf3 server on host hr805
# Starting iperf3 server on host hr806
# Starting iperf3 server on host hr807
# Starting iperf3 server on host hr808
# Starting iperf3 server on host hr809
# Starting iperf3 server on host hr810
# Starting iperf3 server on host hr811
# Starting iperf3 server on host hr812
# Starting iperf3 server on host hr813
# Starting iperf3 server on host hr814
# Starting iperf3 server on host hr815
# Starting iperf3 server on host hr816
# Starting iperf3 server on host hr817
# Starting iperf3 server on host hr818
# Starting iperf3 server on host hr819
# Starting iperf3 server on host hr820
# Starting iperf3 server on host hr821
# Starting iperf3 server on host hr822
# Starting iperf3 server on host hr823
# Starting iperf3 server on host hr824
# Starting iperf3 server on host hr825
# Starting iperf3 server on host hr826
# Starting iperf3 server on host hr827
# Starting iperf3 server on host hr828
# Starting iperf3 server on host hr829
# Starting iperf3 server on host hr830
# Starting iperf3 server on host hr831
# Starting iperf3 server on host hr832
# Starting iperf3 server on host hr833
# Starting iperf3 server on host hr834
# Starting iperf3 server on host hr835
# Starting iperf3 server on host hr836
# Starting iperf3 server on host hr837
# Starting iperf3 server on host hr838
# Starting iperf3 server on host hr839
# Starting iperf3 server on host hr840
# Starting iperf3 server on host hr841
# Starting iperf3 server on host hr842
# Starting iperf3 server on host hr843
# Starting iperf3 server on host hr844
# Starting iperf3 server on host hr845
# Starting iperf3 server on host hr846
# Starting iperf3 server on host hr847
# Starting iperf3 server on host hr848
# Starting iperf3 server on host hr849
# Starting iperf3 server on host hr850
# Starting iperf3 server on host hr851
# Starting iperf3 server on host hr852
# Starting iperf3 server on host hr853
# Starting iperf3 server on host hr854
# Starting iperf3 server on host hr855
# Starting iperf3 server on host hr856
# Starting iperf3 server on host hr857
# Starting iperf3 server on host hr858
# Starting iperf3 server on host hr859
# Starting iperf3 server on host hr860
# Starting iperf3 server on host hr861
# Starting iperf3 server on host hr862
# Starting iperf3 server on host hr863
# Starting iperf3 server on host hr864
# Starting iperf3 server on host hr865
# Starting iperf3 server on host hr866
# Starting iperf3 server on host hr867
# Starting iperf3 server on host hr868
# Starting iperf3 server on host hr869
# Starting iperf3 server on host hr870
# Starting iperf3 server on host hr871
# Starting iperf3 server on host hr872
# Starting iperf3 server on host hr873
# Starting iperf3 server on host hr874
# Starting iperf3 server on host hr875
# Starting iperf3 server on host hr876
# Starting iperf3 server on host hr877
# Starting iperf3 server on host hr878
# Starting iperf3 server on host hr879
# Starting iperf3 server on host hr880
# Starting iperf3 server on host hr881
# Starting iperf3 server on host hr882
# Starting iperf3 server on host hr883
# Starting iperf3 server on host hr884
# Starting iperf3 server on host hr885
# Starting iperf3 server on host hr886
# Starting iperf3 server on host hr887
# Starting iperf3 server on host hr888
# Starting iperf3 server on host hr889
# Starting iperf3 server on host hr890
# Starting iperf3 server on host hr891
# Starting iperf3 server on host hr892
# Starting iperf3 server on host hr893
# Starting iperf3 server on host hr894
# Starting iperf3 server on host hr895
# Starting iperf3 server on host hr896
# Starting iperf3 server on host hr897
# Starting iperf3 server on host hr898
# Starting iperf3 server on host hr899
# Starting iperf3 server on host hr900
# Starting iperf3 server on host hr901
# Starting iperf3 server on host hr902
# Starting iperf3 server on host hr903
# Starting iperf3 server on host hr904
# Starting iperf3 server on host hr905
# Starting iperf3 server on host hr906
# Starting iperf3 server on host hr907
# Starting iperf3 server on host hr908
# Starting iperf3 server on host hr909
# Starting iperf3 server on host hr910
# Starting iperf3 server on host hr911
# Starting iperf3 server on host hr912
# Starting iperf3 server on host hr913
# Starting iperf3 server on host hr914
# Starting iperf3 server on host hr915
# Starting iperf3 server on host hr916
# Starting iperf3 server on host hr917
# Starting iperf3 server on host hr918
# Starting iperf3 server on host hr919
# Starting iperf3 server on host hr920
# Starting iperf3 server on host hr921
# Starting iperf3 server on host hr922
# Starting iperf3 server on host hr923
# Starting iperf3 server on host hr924
# Starting iperf3 server on host hr925
# Starting iperf3 server on host hr926
# Starting iperf3 server on host hr927
# Starting iperf3 server on host hr928
# Starting iperf3 server on host hr929
# Starting iperf3 server on host hr930
# Starting iperf3 server on host hr931
# Starting iperf3 server on host hr932
# Starting iperf3 server on host hr933
# Starting iperf3 server on host hr934
# Starting iperf3 server on host hr935
# Starting iperf3 server on host hr936
# Starting iperf3 server on host hr937
# Starting iperf3 server on host hr938
# Starting iperf3 server on host hr939
# Starting iperf3 server on host hr940
# Starting iperf3 server on host hr941
# Starting iperf3 server on host hr942
# Starting iperf3 server on host hr943
# Starting iperf3 server on host hr944
# Starting iperf3 server on host hr945
# Starting iperf3 server on host hr946
# Starting iperf3 server on host hr947
# Starting iperf3 server on host hr948
# Starting iperf3 server on host hr949
# Starting iperf3 server on host hr950
# Starting iperf3 server on host hr951
# Starting iperf3 server on host hr952
# Starting iperf3 server on host hr953
# Starting iperf3 server on host hr954
# Starting iperf3 server on host hr955
# Starting iperf3 server on host hr956
# Starting iperf3 server on host hr957
# Starting iperf3 server on host hr958
# Starting iperf3 server on host hr959
# Starting iperf3 server on host hr960
# Starting iperf3 server on host hr961
# Starting iperf3 server on host hr962
# Starting iperf3 server on host hr963
# Starting iperf3 server on host hr964
# Starting iperf3 server on host hr965
# Starting iperf3 server on host hr966
# Starting iperf3 server on host hr967
# Starting iperf3 server on host hr968
# Starting iperf3 server on host hr969
# Starting iperf3 server on host hr970
# Starting iperf3 server on host hr971
# Starting iperf3 server on host hr972
# Starting iperf3 server on host hr973
# Starting iperf3 server on host hr974
# Starting iperf3 server on host hr975
# Starting iperf3 server on host hr976
# Starting iperf3 server on host hr977
# Starting iperf3 server on host hr978
# Starting iperf3 server on host hr979
# Starting iperf3 server on host hr980
# Starting iperf3 server on host hr981
# Starting iperf3 server on host hr982
# Starting iperf3 server on host hr983
# Starting iperf3 server on host hr984
# Starting iperf3 server on host hr985
# Starting iperf3 server on host hr986
# Starting iperf3 server on host hr987
# Starting iperf3 server on host hr988
# Starting iperf3 server on host hr989
# Starting iperf3 server on host hr990
# Starting iperf3 server on host hr991
# Starting iperf3 server on host hr992
# Starting iperf3 server on host hr993
# Starting iperf3 server on host hr994
# Starting iperf3 server on host hr995
# Starting iperf3 server on host hr996
# Starting iperf3 server on host hr997
# Starting iperf3 server on host hr998
# Starting iperf3 server on host hr999
# Starting iperf3 server on host hr1000
# Starting iperf3 server on host hr1001
# Starting iperf3 server on host hr1002
# Starting iperf3 server on host hr1003
# Starting iperf3 server on host hr1004
# Starting iperf3 server on host hr1005
# Starting iperf3 server on host hr1006
# Starting iperf3 server on host hr1007
# Starting iperf3 server on host hr1008
# Starting iperf3 server on host hr1009
# Starting iperf3 server on host hr1010
# Starting iperf3 server on host hr1011
# Starting iperf3 server on host hr1012
# Starting iperf3 server on host hr1013
# Starting iperf3 server on host hr1014
# Starting iperf3 server on host hr1015
# Starting iperf3 server on host hr1016
# Starting iperf3 server on host hr1017
# Starting iperf3 server on host hr1018
# Starting iperf3 server on host hr1019
# Starting iperf3 server on host hr1020
# Starting iperf3 server on host hr1021
# Starting iperf3 server on host hr1022
# Starting iperf3 server on host hr1023
# Starting iperf3 server on host hr1024

# %% [markdown]
# ## 6.2 Running the Test

# %% [markdown]
# ### 6.2.1 Starting the iPerf3 clients

# %%
for i in range(1, num_hosts + 1):
    h1.execute_thread(f"mininet/util/m hs{i} iperf3 -c 172.17.0.{i} -J > results/hs{i}_out.json &")

# %% [markdown]
# ### 6.2.2 Getting the JSON Files

# %%
for i in range(1, num_hosts + 1):
    h1.download_file(f"results/hs{i}_out.json",f"results/hs{i}_out.json")

# %% [markdown]
# ## 6.3 Plotting the Results

# %% [markdown]
# ### 6.3.1 Plot as a Function of Time

# %%
import matplotlib.pyplot as plt
import numpy as np
import json
import matplotlib

# Load throughput data from JSON
def extract_iperf_timming(filename):   
    with open(filename) as f:
        data = json.load(f)
    dur = int(data['end']['sum_sent']['end'])
    result = []
    for i in range(0, dur):
       result.append(float(data['intervals'][i]['sum']['bits_per_second']) / 1e9)
    
    return result

# Plot setup for fair and clean visuals
def setup_plot(font_size=26):
    font = {'family': 'normal', 'weight': 'normal', 'size': font_size}
    matplotlib.rc('font', **font)
    fig, axes = plt.subplots(2, 1, sharex=True, figsize=(10, 8))
    fig.subplots_adjust(hspace=0.1)
    for ax in axes:
        ax.grid(True, which="both", lw=0.3, linestyle=(0, (1, 10)), color='black')
    return fig, axes

# Calculate fairness based on throughput
def calculate_fairness(cubic, bbr3):
    return [
        100 * (c + b) ** 2 / (2 * (c ** 2 + b ** 2))
        for c, b in zip(cubic, bbr3)
    ]

# Main plotting function for experiment results
def plot_results(throughput, filename="output.pdf"):
    #fairness = calculate_fairness(cubic, bbr3)
    fig, axes = setup_plot()
    t = list(range(0, len(throughput)))
    # Plotting fairness and throughput
   
    axes[1].plot(t, throughput, '#2D72B7', linewidth=2, label='Agg. Tput', marker='o')

    # Set labels and legends
    axes[0].set_ylabel('Fairness [%]')
    axes[1].set_ylabel('Throughput [Gbps]')
    axes[1].set_xlabel('Buffer size [BDP]')
    axes[0].legend(loc="lower right")
    axes[1].legend(loc="upper right", ncol=2)
    axes[0].set_ylim([50, 105])
    axes[1].set_ylim([0, 100])

    fig.savefig(filename, bbox_inches='tight')

def main():
    th = []
    # Extract the Throughput of each flow
    for i in range(1, num_hosts + 1):
        th.append(extract_iperf_timming(f"results/hs{i}_out.json"))

    # 
    agg_th = [sum(column) for column in zip(*th)]
    plot_results(agg_th, filename="output.pdf")
        
        
    #setup_plot(font_size=26)

            
if __name__ == '__main__':
    main()
# Out:
# /tmp/ipykernel_160/4248212304.py:47: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(loc="lower right")
